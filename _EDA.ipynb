# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pickle
import tensorflow as tf
from RecFunctions import type_prod_histogram, type_problem_histogram

# %%
with open('pickles/df1.pickle', 'rb') as f:
    df = pickle.load(f)

# %%
df.groupby(['brandName']).mean()
# Out:
#                                price       age  darkcircles      acne  \
# brandName
# 37 Actives                132.000000  1.000000     0.000000  0.000000
# ARCONA                     47.050000  0.296000     0.000000  0.352000
# ARgENTUM                  225.000000  1.000000     0.000000  1.000000
# Aesop                      61.666667  0.000000     0.000000  0.000000
# Alchimie Forever           50.500000  0.000000     0.000000  0.500000
# Avene                      22.180905  0.015075     0.000000  0.120603
# B. Kamins                  33.266667  0.000000     0.666667  0.000000
# BABOR                     238.333333  0.666667     0.000000  0.000000
# Balance Me                 11.000000  0.000000     0.000000  1.000000
# Beauty ORA                 31.600000  0.200000     0.000000  0.000000
# Bioderma                   19.125000  0.000000     0.000000  0.500000
# Bioelements                36.250000  1.000000     0.000000  0.000000
# Boots No7                  43.323333  1.000000     0.000000  0.000000
# Caudalie                   54.422222  0.318519     0.000000  0.029630
# Cellex-C                  101.444444  1.000000     0.000000  0.000000
# Clark's Botanicals         98.000000  1.000000     0.000000  0.000000
# Colorescience              69.000000  1.000000     1.000000  0.000000
# CosMedix                   42.000000  0.000000     0.000000  1.000000
# DDF                        51.566667  0.666667     0.000000  0.000000
# DERMAdoctor                68.904977  0.280543     0.651584  0.828054
# DHC                         9.000000  0.000000     1.000000  0.000000
# Decorté                    95.000000  1.000000     0.000000  0.000000
# Dermalogica                58.910000  0.700000     0.000000  0.012500
# Dermelect Cosmeceuticals   36.875000  0.625000     0.000000  0.000000
# Dr Dennis Gross Skincare   75.520000  0.960000     0.360000  0.000000
# Dr. Brandt                 58.130435  0.130435     0.000000  0.000000
# Dr. Hauschka               66.333333  0.000000     0.000000  0.000000
# Dr. Michelle Copeland     157.600000  1.000000     0.000000  0.000000
# ESPA                       68.466667  0.266667     0.000000  0.000000
# Elemis                    155.760000  0.960000     0.000000  0.000000
# ...                              ...       ...          ...       ...
# Paula's Choice             30.204859  0.950210     0.007199  0.944811
# Perricone MD               85.600000  0.242857     0.700000  0.114286
# Peter Thomas Roth          73.017241  0.896552     0.000000  0.000000
# Pevonia Botanica          118.750000  0.500000     0.000000  0.000000
# Purlisse                   32.000000  0.000000     0.000000  0.000000
# REN Clean Skincare         57.000000  1.000000     0.000000  1.000000
# Replenix, Topix            69.767568  1.000000     0.000000  0.000000
# Rodial                     89.268657  0.985075     0.000000  0.985075
# SRS, Topix                118.000000  1.000000     0.000000  0.000000
# Skin Authority             89.583333  0.666667     0.000000  0.166667
# SkinCeuticals              93.419801  0.824445     0.000000  0.443184
# SkinMedica                 99.497982  0.616559     0.032154  0.565916
# Slip                       85.032680  0.000000     0.000000  1.000000
# StriVectin                 73.437500  1.000000     0.281250  0.000000
# Sundari                    58.551724  0.000000     0.000000  0.000000
# Sunday Riley              103.803681  0.981595     0.000000  1.000000
# Supermood                  66.333333  0.166667     0.166667  0.000000
# Thalgo                     78.000000  0.500000     0.000000  0.000000
# The Ordinary                8.761590  0.605505     0.027523  0.000000
# The Perfect V              35.500000  0.000000     0.000000  0.000000
# Topix                     129.500000  0.000000     1.000000  0.000000
# UltraLuxe                  60.000000  0.000000     0.000000  0.000000
# Vichy                      52.127273  0.727273     0.000000  0.000000
# Wilma Schumann             35.000000  0.000000     0.000000  0.000000
# Yon-Ka Paris Skincare      70.235294  0.294118     0.000000  0.588235
# Z. Bigatti                 70.610000  1.000000     0.000000  0.000000
# Zelens                    205.000000  1.000000     0.000000  0.000000
# iS Clinical               118.476190  0.619048     0.000000  0.380952
# skyn ICELAND               42.583333  0.166667     0.000000  0.416667
# this works                 75.666667  0.666667     0.000000  0.000000
#
#                                dry   redness  sensitive      oily    normal  \
# brandName
# 37 Actives                0.000000  0.000000   0.000000  0.000000  0.000000
# ARCONA                    0.256000  0.000000   0.000000  0.160000  0.000000
# ARgENTUM                  1.000000  1.000000   1.000000  1.000000  1.000000
# Aesop                     0.666667  0.000000   0.333333  0.000000  0.000000
# Alchimie Forever          0.500000  0.000000   0.000000  0.000000  0.000000
# Avene                     0.814070  0.000000   0.130653  0.809045  0.035176
# B. Kamins                 0.000000  0.000000   0.000000  0.333333  0.000000
# BABOR                     0.333333  0.000000   0.000000  0.000000  0.000000
# Balance Me                0.000000  0.000000   1.000000  1.000000  1.000000
# Beauty ORA                0.800000  0.000000   0.800000  0.000000  0.000000
# Bioderma                  0.250000  0.000000   0.250000  0.000000  0.000000
# Bioelements               0.000000  0.000000   0.000000  0.000000  0.000000
# Boots No7                 0.000000  0.000000   0.000000  0.000000  0.000000
# Caudalie                  0.851852  0.000000   0.459259  0.222222  0.422222
# Cellex-C                  0.666667  0.000000   0.000000  0.000000  0.000000
# Clark's Botanicals        0.000000  0.000000   0.000000  0.000000  0.000000
# Colorescience             0.000000  0.000000   0.000000  0.000000  0.000000
# CosMedix                  0.000000  0.000000   0.000000  0.000000  0.000000
# DDF                       0.000000  0.000000   0.333333  0.000000  0.000000
# DERMAdoctor               0.117647  0.221719   0.000000  0.334842  0.873303
# DHC                       0.000000  0.000000   0.000000  0.000000  0.000000
# Decorté                   0.000000  0.000000   1.000000  0.000000  0.000000
# Dermalogica               0.262500  0.000000   0.612500  0.012500  0.225000
# Dermelect Cosmeceuticals  0.000000  0.125000   0.000000  0.250000  0.000000
# Dr Dennis Gross Skincare  0.040000  0.000000   0.160000  0.000000  0.160000
# Dr. Brandt                0.086957  0.000000   0.000000  0.347826  0.434783
# Dr. Hauschka              0.333333  0.666667   0.000000  0.000000  0.000000
# Dr. Michelle Copeland     0.000000  0.000000   0.000000  0.000000  0.000000
# ESPA                      0.600000  0.000000   0.133333  0.000000  0.866667
# Elemis                    0.040000  0.160000   0.000000  0.000000  0.000000
# ...                            ...       ...        ...       ...       ...
# Paula's Choice            0.874625  0.882424   0.056389  0.938212  0.926815
# Perricone MD              0.285714  0.128571   0.628571  0.371429  0.128571
# Peter Thomas Roth         0.051724  0.000000   0.000000  0.017241  0.034483
# Pevonia Botanica          0.500000  0.000000   0.000000  0.000000  0.000000
# Purlisse                  1.000000  0.000000   0.000000  0.000000  0.000000
# REN Clean Skincare        0.000000  0.000000   0.000000  0.000000  1.000000
# Replenix, Topix           0.729730  0.000000   0.000000  0.000000  0.000000
# Rodial                    0.000000  0.000000   0.716418  0.985075  0.014925
# SRS, Topix                0.000000  0.000000   0.000000  0.000000  0.000000
# Skin Authority            0.000000  0.000000   0.000000  0.166667  0.000000
# SkinCeuticals             0.882639  0.000648   0.758146  0.619225  0.930135
# SkinMedica                0.544212  0.000000   0.019293  0.732315  0.803055
# Slip                      0.000000  1.000000   1.000000  0.000000  0.941176
# StriVectin                0.375000  0.000000   0.000000  0.000000  0.000000
# Sundari                   0.241379  0.000000   0.000000  0.551724  0.620690
# Sunday Riley              0.000000  0.000000   0.981595  0.000000  0.981595
# Supermood                 0.333333  0.166667   0.000000  0.166667  0.000000
# Thalgo                    0.000000  0.000000   0.000000  0.000000  0.500000
# The Ordinary              0.651376  0.122324   0.012232  0.159021  0.302752
# The Perfect V             0.000000  0.000000   0.000000  0.000000  1.000000
# Topix                     0.000000  0.000000   0.000000  0.000000  0.000000
# UltraLuxe                 0.000000  0.000000   0.000000  1.000000  0.000000
# Vichy                     0.454545  0.000000   0.090909  0.000000  0.454545
# Wilma Schumann            1.000000  0.000000   1.000000  0.000000  0.000000
# Yon-Ka Paris Skincare     0.117647  0.000000   0.000000  0.000000  0.000000
# Z. Bigatti                0.000000  0.000000   0.000000  0.000000  0.000000
# Zelens                    0.000000  0.000000   0.000000  0.000000  0.000000
# iS Clinical               0.380952  0.000000   0.000000  0.380952  0.000000
# skyn ICELAND              0.416667  0.000000   0.000000  0.000000  0.000000
# this works                0.000000  0.000000   0.000000  0.000000  0.333333
#
#                           cleanser  ...  moisturizer      balm       oil  \
# brandName                           ...
# 37 Actives                0.000000  ...     0.000000  0.000000  0.000000
# ARCONA                    0.004000  ...     0.164000  0.000000  0.000000
# ARgENTUM                  0.000000  ...     1.000000  0.000000  0.000000
# Aesop                     0.000000  ...     0.333333  0.000000  0.000000
# Alchimie Forever          0.500000  ...     0.000000  0.000000  0.000000
# Avene                     0.005025  ...     0.165829  0.000000  0.000000
# B. Kamins                 0.333333  ...     0.000000  0.000000  0.000000
# BABOR                     0.000000  ...     0.333333  0.000000  0.000000
# Balance Me                1.000000  ...     0.000000  0.000000  0.000000
# Beauty ORA                0.000000  ...     0.000000  0.000000  0.000000
# Bioderma                  0.000000  ...     0.750000  0.000000  0.000000
# Bioelements               0.000000  ...     0.000000  0.000000  0.000000
# Boots No7                 0.000000  ...     0.666667  0.000000  0.000000
# Caudalie                  0.162963  ...     0.125926  0.000000  0.000000
# Cellex-C                  0.000000  ...     0.666667  0.000000  0.000000
# Clark's Botanicals        0.000000  ...     0.000000  0.000000  0.000000
# Colorescience             0.000000  ...     0.000000  0.000000  0.000000
# CosMedix                  0.000000  ...     0.000000  0.000000  0.000000
# DDF                       0.333333  ...     0.000000  0.000000  0.000000
# DERMAdoctor               0.162896  ...     0.167421  0.000000  0.000000
# DHC                       0.000000  ...     1.000000  0.000000  0.000000
# Decorté                   0.000000  ...     0.000000  0.000000  0.000000
# Dermalogica               0.025000  ...     0.037500  0.000000  0.237500
# Dermelect Cosmeceuticals  0.000000  ...     0.000000  0.000000  0.000000
# Dr Dennis Gross Skincare  0.080000  ...     0.133333  0.000000  0.000000
# Dr. Brandt                0.347826  ...     0.521739  0.000000  0.000000
# Dr. Hauschka              0.000000  ...     0.666667  0.000000  0.333333
# Dr. Michelle Copeland     0.000000  ...     0.000000  0.000000  0.000000
# ESPA                      0.000000  ...     0.400000  0.000000  0.000000
# Elemis                    0.240000  ...     0.240000  0.000000  0.000000
# ...                            ...  ...          ...       ...       ...
# Paula's Choice            0.004799  ...     0.043191  0.000000  0.000000
# Perricone MD              0.028571  ...     0.414286  0.000000  0.242857
# Peter Thomas Roth         0.189655  ...     0.172414  0.000000  0.017241
# Pevonia Botanica          0.000000  ...     0.000000  0.000000  0.000000
# Purlisse                  0.000000  ...     0.000000  0.000000  0.000000
# REN Clean Skincare        0.000000  ...     1.000000  0.000000  0.000000
# Replenix, Topix           0.000000  ...     0.000000  0.000000  0.000000
# Rodial                    0.000000  ...     0.716418  0.000000  0.014925
# SRS, Topix                0.000000  ...     0.000000  0.000000  0.000000
# Skin Authority            0.000000  ...     0.000000  0.000000  0.000000
# SkinCeuticals             0.007943  ...     0.351597  0.009078  0.000000
# SkinMedica                0.136656  ...     0.208199  0.000000  0.000000
# Slip                      0.000000  ...     0.000000  0.000000  0.000000
# StriVectin                0.000000  ...     0.031250  0.000000  0.250000
# Sundari                   0.000000  ...     0.724138  0.000000  0.068966
# Sunday Riley              0.000000  ...     0.000000  0.000000  0.000000
# Supermood                 0.000000  ...     0.500000  0.000000  0.000000
# Thalgo                    0.000000  ...     1.000000  0.000000  0.000000
# The Ordinary              0.000000  ...     0.030581  0.064220  0.143731
# The Perfect V             0.000000  ...     0.500000  0.000000  0.000000
# Topix                     0.000000  ...     0.000000  0.000000  0.000000
# UltraLuxe                 0.000000  ...     0.000000  0.000000  0.000000
# Vichy                     0.181818  ...     0.363636  0.000000  0.090909
# Wilma Schumann            0.000000  ...     1.000000  0.000000  0.000000
# Yon-Ka Paris Skincare     0.000000  ...     0.352941  0.000000  0.000000
# Z. Bigatti                0.000000  ...     0.000000  0.000000  0.000000
# Zelens                    0.000000  ...     0.000000  0.000000  0.000000
# iS Clinical               0.000000  ...     0.000000  0.000000  0.000000
# skyn ICELAND              0.000000  ...     0.416667  0.000000  0.000000
# this works                0.000000  ...     0.666667  0.000000  0.000000
#
#                               mask      peel       lip       eye  supplement  \
# brandName
# 37 Actives                0.000000  0.000000  0.000000  0.000000    0.000000
# ARCONA                    0.052000  0.204000  0.000000  0.088000    0.000000
# ARgENTUM                  0.000000  0.000000  0.000000  0.000000    0.000000
# Aesop                     0.000000  0.000000  0.000000  0.000000    0.000000
# Alchimie Forever          0.500000  0.000000  0.000000  0.000000    0.000000
# Avene                     0.005025  0.000000  0.005025  0.000000    0.000000
# B. Kamins                 0.000000  0.000000  0.000000  0.000000    0.000000
# BABOR                     0.333333  0.000000  0.000000  0.000000    0.000000
# Balance Me                0.000000  0.000000  0.000000  0.000000    0.000000
# Beauty ORA                0.000000  0.000000  0.000000  0.000000    0.000000
# Bioderma                  0.000000  0.000000  0.000000  0.000000    0.000000
# Bioelements               0.000000  0.000000  0.000000  0.000000    0.000000
# Boots No7                 0.000000  0.000000  0.000000  0.000000    0.000000
# Caudalie                  0.000000  0.000000  0.000000  0.074074    0.000000
# Cellex-C                  0.000000  0.000000  0.000000  0.000000    0.000000
# Clark's Botanicals        0.000000  0.000000  0.000000  0.000000    0.000000
# Colorescience             0.000000  0.000000  0.000000  0.000000    0.000000
# CosMedix                  1.000000  0.000000  0.000000  0.000000    0.000000
# DDF                       0.000000  0.000000  0.000000  0.000000    0.000000
# DERMAdoctor               0.000000  0.601810  0.000000  0.162896    0.000000
# DHC                       1.000000  0.000000  0.000000  1.000000    0.000000
# Decorté                   0.000000  0.000000  0.000000  0.000000    0.000000
# Dermalogica               0.612500  0.000000  0.050000  0.012500    0.000000
# Dermelect Cosmeceuticals  0.000000  0.000000  0.625000  0.000000    0.000000
# Dr Dennis Gross Skincare  0.160000  0.386667  0.000000  0.160000    0.000000
# Dr. Brandt                0.000000  0.000000  0.000000  0.086957    0.000000
# Dr. Hauschka              0.000000  0.000000  0.000000  0.000000    0.000000
# Dr. Michelle Copeland     0.000000  0.000000  0.000000  0.000000    0.000000
# ESPA                      0.600000  0.000000  0.000000  0.000000    0.000000
# Elemis                    0.160000  0.160000  0.000000  0.240000    0.160000
# ...                            ...       ...       ...       ...         ...
# Paula's Choice            0.000000  0.000000  0.000000  0.000000    0.000000
# Perricone MD              0.014286  0.014286  0.014286  0.428571    0.028571
# Peter Thomas Roth         0.275862  0.017241  0.000000  0.172414    0.000000
# Pevonia Botanica          0.000000  0.000000  0.000000  0.000000    0.000000
# Purlisse                  0.000000  0.000000  1.000000  0.000000    0.000000
# REN Clean Skincare        0.000000  0.000000  0.000000  0.000000    0.000000
# Replenix, Topix           0.000000  0.000000  0.000000  0.000000    0.000000
# Rodial                    0.000000  0.000000  0.000000  0.268657    0.000000
# SRS, Topix                0.000000  0.000000  0.000000  0.000000    0.000000
# Skin Authority            0.000000  0.000000  0.000000  0.000000    0.000000
# SkinCeuticals             0.000000  0.041174  0.000648  0.032744    0.000000
# SkinMedica                0.000000  0.000000  0.000000  0.032154    0.000000
# Slip                      0.000000  0.000000  0.000000  0.000000    0.000000
# StriVectin                0.000000  0.000000  0.000000  0.531250    0.000000
# Sundari                   0.206897  0.000000  0.000000  0.000000    0.000000
# Sunday Riley              0.000000  0.000000  0.000000  0.000000    0.000000
# Supermood                 0.000000  0.000000  0.000000  0.000000    0.333333
# Thalgo                    0.000000  0.000000  0.000000  0.000000    0.000000
# The Ordinary              0.000000  0.021407  0.000000  0.000000    0.000000
# The Perfect V             0.000000  0.000000  0.000000  0.000000    0.000000
# Topix                     0.000000  0.000000  0.000000  0.000000    0.000000
# UltraLuxe                 0.000000  0.000000  0.000000  0.000000    0.000000
# Vichy                     0.000000  0.000000  0.000000  0.000000    0.000000
# Wilma Schumann            0.000000  0.000000  0.000000  0.000000    0.000000
# Yon-Ka Paris Skincare     0.000000  0.000000  0.000000  0.000000    0.000000
# Z. Bigatti                0.000000  0.000000  0.000000  0.000000    0.000000
# Zelens                    1.000000  0.000000  0.000000  0.000000    0.000000
# iS Clinical               0.000000  0.000000  0.000000  0.000000    0.000000
# skyn ICELAND              0.000000  0.375000  0.000000  0.125000    0.000000
# this works                0.333333  0.000000  0.000000  0.000000    0.000000
#
#                               tool    rating
# brandName
# 37 Actives                0.000000  4.833333
# ARCONA                    0.000000  4.320000
# ARgENTUM                  0.000000  5.000000
# Aesop                     0.000000  5.000000
# Alchimie Forever          0.000000  4.571429
# Avene                     0.000000  4.879397
# B. Kamins                 0.000000  5.000000
# BABOR                     0.000000  5.000000
# Balance Me                0.000000  5.000000
# Beauty ORA                1.000000  4.800000
# Bioderma                  0.000000  5.000000
# Bioelements               0.000000  5.000000
# Boots No7                 0.000000  5.000000
# Caudalie                  0.000000  4.488889
# Cellex-C                  0.000000  4.861111
# Clark's Botanicals        0.000000  5.000000
# Colorescience             0.000000  4.666667
# CosMedix                  0.000000  5.000000
# DDF                       0.000000  3.833333
# DERMAdoctor               0.601810  4.343891
# DHC                       0.000000  5.000000
# Decorté                   0.000000  5.000000
# Dermalogica               0.000000  4.775000
# Dermelect Cosmeceuticals  0.000000  3.125000
# Dr Dennis Gross Skincare  0.000000  4.813333
# Dr. Brandt                0.043478  4.217391
# Dr. Hauschka              0.000000  4.333333
# Dr. Michelle Copeland     0.000000  4.500000
# ESPA                      0.000000  4.200000
# Elemis                    0.000000  4.560000
# ...                            ...       ...
# Paula's Choice            0.000000  4.872226
# Perricone MD              0.114286  4.871429
# Peter Thomas Roth         0.000000  4.206897
# Pevonia Botanica          0.000000  5.000000
# Purlisse                  0.000000  5.000000
# REN Clean Skincare        0.000000  5.000000
# Replenix, Topix           0.000000  4.675676
# Rodial                    0.000000  4.761194
# SRS, Topix                0.000000  5.000000
# Skin Authority            0.166667  4.666667
# SkinCeuticals             0.000162  4.530556
# SkinMedica                0.000000  4.733923
# Slip                      0.000000  4.941176
# StriVectin                0.000000  4.687500
# Sundari                   0.000000  3.931034
# Sunday Riley              0.000000  4.312883
# Supermood                 0.000000  5.000000
# Thalgo                    0.000000  5.000000
# The Ordinary              0.143731  4.743119
# The Perfect V             0.000000  4.500000
# Topix                     0.000000  5.000000
# UltraLuxe                 0.000000  5.000000
# Vichy                     0.000000  4.545455
# Wilma Schumann            0.000000  5.000000
# Yon-Ka Paris Skincare     0.000000  4.352941
# Z. Bigatti                0.000000  4.150000
# Zelens                    0.000000  5.000000
# iS Clinical               0.000000  4.595238
# skyn ICELAND              0.000000  4.291667
# this works                0.000000  4.666667
#
# [103 rows x 27 columns]

# %%
with open('userratingsDF.pickle', 'rb') as f:
    rdf = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-175c42c3a891> in <module>
# ----> 1 with open('userratingsDF.pickle', 'rb') as f:
#       2     rdf = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'userratingsDF.pickle'

# %%
plt.figure(figsize=(8,6))
sns.distplot(df.rating)
plt.title('All Ratings Distribution')
# Out:
# Text(0.5, 1.0, 'All Ratings Distribution')

# %%
plt.figure(figsize=(40,40))
df.groupby(['brandName']).mean().index.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.savefig('VennDiagram_AllBrands.png')

# %%
plt.figure(figsize=(10,10))
sns.distplot(df.brandName.value_counts())

# %%
plt.figure(figsize=(8,8))
sns.distplot(df.rating)
plt.title('All Ratings Distribution')
plt.ylabel('Density')
# plt.savefig('AllRatingsDistribution.png')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(8,8))
sns.distplot(df.price)
plt.title('All Prices Distribution')
plt.ylabel('Density')
plt.savefig('AllPricesDistribution.png')

# %%
type_problem_histogram(df,'allData')
type_prod_histogram(df,'allData')
# Out:
# {'age': 10340, 'darkCircles': 514, 'acne': 6781, 'dry': 10226, 'redness': 2748, 'sensitive': 6827, 'oily': 8158, 'normal': 10801}
# {'oil': 295, 'cleanser': 738, 'exfoliator': 2404, 'remover': 29, 'toner': 931, 'mist': 258, 'treatment': 4320, 'serum': 4776, 'lotion': 129, 'moisturizer': 3504, 'balm': 167, 'mask': 506, 'peel': 565, 'lip': 40, 'eye': 529, 'supplment': 100, 'tool': 476}

# %%
type_problem_histogram(df[df['age']==1],'age')
type_prod_histogram(df[df['age']==1],'age')
# Out:
# {'age': 773, 'darkCircles': 50, 'acne': 111, 'dry': 223, 'redness': 25, 'sensitive': 132, 'oily': 124, 'normal': 222}
# {'oil': 22, 'cleanser': 30, 'exfoliator': 48, 'remover': 0, 'toner': 41, 'mist': 13, 'treatment': 239, 'serum': 250, 'lotion': 26, 'moisturizer': 211, 'balm': 11, 'mask': 35, 'peel': 27, 'lip': 6, 'eye': 77, 'supplment': 3, 'tool': 36}

# %%
type_problem_histogram(df[df['darkcircles']==1],'darkCircles')
type_prod_histogram(df[df['darkcircles']==1],'darkCircles')
# Out:
# {'age': 50, 'darkCircles': 118, 'acne': 5, 'dry': 25, 'redness': 0, 'sensitive': 13, 'oily': 12, 'normal': 18}
# {'oil': 4, 'cleanser': 5, 'exfoliator': 16, 'remover': 0, 'toner': 10, 'mist': 2, 'treatment': 35, 'serum': 12, 'lotion': 3, 'moisturizer': 24, 'balm': 4, 'mask': 10, 'peel': 10, 'lip': 2, 'eye': 47, 'supplment': 2, 'tool': 12}

# %%
type_problem_histogram(df[df['acne']==1],'acne')
type_prod_histogram(df[df['acne']==1],'acne')
# Out:
# {'age': 111, 'darkCircles': 5, 'acne': 340, 'dry': 88, 'redness': 66, 'sensitive': 140, 'oily': 112, 'normal': 192}
# {'oil': 1, 'cleanser': 39, 'exfoliator': 36, 'remover': 2, 'toner': 15, 'mist': 0, 'treatment': 103, 'serum': 71, 'lotion': 12, 'moisturizer': 52, 'balm': 0, 'mask': 14, 'peel': 17, 'lip': 0, 'eye': 7, 'supplment': 2, 'tool': 26}

# %%
type_problem_histogram(df[df['dry']==1],'dry')
type_prod_histogram(df[df['dry']==1],'dry')
# Out:
# {'age': 223, 'darkCircles': 25, 'acne': 88, 'dry': 576, 'redness': 38, 'sensitive': 149, 'oily': 147, 'normal': 227}
# {'oil': 28, 'cleanser': 62, 'exfoliator': 38, 'remover': 5, 'toner': 49, 'mist': 14, 'treatment': 125, 'serum': 137, 'lotion': 22, 'moisturizer': 192, 'balm': 22, 'mask': 27, 'peel': 20, 'lip': 16, 'eye': 41, 'supplment': 2, 'tool': 23}

# %%
type_problem_histogram(df[df['redness']==1],'redness')
type_prod_histogram(df[df['redness']==1],'redness')
# Out:
# {'age': 25, 'darkCircles': 0, 'acne': 66, 'dry': 38, 'redness': 144, 'sensitive': 95, 'oily': 31, 'normal': 71}
# {'oil': 6, 'cleanser': 6, 'exfoliator': 14, 'remover': 0, 'toner': 7, 'mist': 6, 'treatment': 7, 'serum': 20, 'lotion': 3, 'moisturizer': 25, 'balm': 4, 'mask': 4, 'peel': 0, 'lip': 2, 'eye': 6, 'supplment': 0, 'tool': 5}

# %%
type_problem_histogram(df[df['sensitive']==1],'sensitive')
type_prod_histogram(df[df['sensitive']==1],'sensitive')
# Out:
# {'age': 132, 'darkCircles': 13, 'acne': 140, 'dry': 149, 'redness': 95, 'sensitive': 395, 'oily': 100, 'normal': 196}
# {'oil': 11, 'cleanser': 38, 'exfoliator': 29, 'remover': 2, 'toner': 28, 'mist': 8, 'treatment': 81, 'serum': 86, 'lotion': 14, 'moisturizer': 94, 'balm': 12, 'mask': 6, 'peel': 14, 'lip': 9, 'eye': 12, 'supplment': 0, 'tool': 12}

# %%
type_problem_histogram(df[df['oily']==1],'oily skin')
type_prod_histogram(df[df['oily']==1],'oily skin')
# Out:
# {'age': 124, 'darkCircles': 12, 'acne': 112, 'dry': 147, 'redness': 31, 'sensitive': 100, 'oily': 347, 'normal': 164}
# {'oil': 2, 'cleanser': 49, 'exfoliator': 50, 'remover': 3, 'toner': 51, 'mist': 11, 'treatment': 103, 'serum': 88, 'lotion': 10, 'moisturizer': 95, 'balm': 1, 'mask': 17, 'peel': 18, 'lip': 0, 'eye': 16, 'supplment': 2, 'tool': 14}

# %%
type_problem_histogram(df[df['normal']==1],'normal skin')
type_prod_histogram(df[df['normal']==1],'normal skin')
# Out:
# {'age': 222, 'darkCircles': 18, 'acne': 192, 'dry': 227, 'redness': 71, 'sensitive': 196, 'oily': 164, 'normal': 555}
# {'oil': 9, 'cleanser': 71, 'exfoliator': 47, 'remover': 5, 'toner': 47, 'mist': 8, 'treatment': 143, 'serum': 136, 'lotion': 19, 'moisturizer': 149, 'balm': 14, 'mask': 28, 'peel': 24, 'lip': 5, 'eye': 32, 'supplment': 0, 'tool': 27}

# %%
type_problem_histogram(df[df['cleanser']==1],'cleanser')
type_prod_histogram(df[df['cleanser']==1],'cleanser')
# Out:
# {'age': 30, 'darkCircles': 5, 'acne': 39, 'dry': 62, 'redness': 6, 'sensitive': 38, 'oily': 49, 'normal': 71}
# {'oil': 8, 'cleanser': 193, 'exfoliator': 25, 'remover': 8, 'toner': 21, 'mist': 6, 'treatment': 21, 'serum': 11, 'lotion': 9, 'moisturizer': 17, 'balm': 1, 'mask': 10, 'peel': 8, 'lip': 3, 'eye': 10, 'supplment': 2, 'tool': 22}

# %%
type_problem_histogram(df[df['oil']==1],'oil')
type_prod_histogram(df[df['oil']==1],'oil')
# Out:
# {'age': 22, 'darkCircles': 4, 'acne': 1, 'dry': 28, 'redness': 6, 'sensitive': 11, 'oily': 2, 'normal': 9}
# {'oil': 62, 'cleanser': 8, 'exfoliator': 4, 'remover': 0, 'toner': 3, 'mist': 3, 'treatment': 14, 'serum': 12, 'lotion': 5, 'moisturizer': 5, 'balm': 2, 'mask': 3, 'peel': 2, 'lip': 3, 'eye': 2, 'supplment': 2, 'tool': 0}

# %%
#No matter what problem someone has, everyone should use an exfoliator!!
type_problem_histogram(df[df['exfoliator']==1],'exfoliator')
type_prod_histogram(df[df['exfoliator']==1],'exfoliator')
# Out:
# {'age': 48, 'darkCircles': 16, 'acne': 36, 'dry': 38, 'redness': 14, 'sensitive': 29, 'oily': 50, 'normal': 47}
# {'oil': 4, 'cleanser': 25, 'exfoliator': 121, 'remover': 1, 'toner': 13, 'mist': 3, 'treatment': 25, 'serum': 23, 'lotion': 4, 'moisturizer': 15, 'balm': 2, 'mask': 8, 'peel': 39, 'lip': 3, 'eye': 6, 'supplment': 2, 'tool': 19}

# %%
type_problem_histogram(df[df['makeup-removers']==1],'makeup remover')
type_prod_histogram(df[df['makeup-removers']==1],'makeup remover')
# Out:
# {'age': 0, 'darkCircles': 0, 'acne': 2, 'dry': 5, 'redness': 0, 'sensitive': 2, 'oily': 3, 'normal': 5}
# {'oil': 0, 'cleanser': 8, 'exfoliator': 1, 'remover': 9, 'toner': 4, 'mist': 0, 'treatment': 0, 'serum': 0, 'lotion': 0, 'moisturizer': 0, 'balm': 1, 'mask': 0, 'peel': 0, 'lip': 0, 'eye': 3, 'supplment': 0, 'tool': 3}

# %%
#No matter what skin problem, everyone should use a toner!!
type_problem_histogram(df[df['toner']==1],'toner')
type_prod_histogram(df[df['toner']==1],'toner')
# Out:
# {'age': 41, 'darkCircles': 10, 'acne': 15, 'dry': 49, 'redness': 7, 'sensitive': 28, 'oily': 51, 'normal': 47}
# {'oil': 3, 'cleanser': 21, 'exfoliator': 13, 'remover': 4, 'toner': 116, 'mist': 16, 'treatment': 26, 'serum': 5, 'lotion': 11, 'moisturizer': 10, 'balm': 1, 'mask': 2, 'peel': 2, 'lip': 3, 'eye': 6, 'supplment': 2, 'tool': 6}

# %%
type_problem_histogram(df[df['mist']==1],'mist')
type_prod_histogram(df[df['mist']==1],'mist')
# Out:
# {'age': 13, 'darkCircles': 2, 'acne': 0, 'dry': 14, 'redness': 6, 'sensitive': 8, 'oily': 11, 'normal': 8}
# {'oil': 3, 'cleanser': 6, 'exfoliator': 3, 'remover': 0, 'toner': 16, 'mist': 36, 'treatment': 6, 'serum': 5, 'lotion': 4, 'moisturizer': 6, 'balm': 1, 'mask': 3, 'peel': 3, 'lip': 3, 'eye': 2, 'supplment': 2, 'tool': 0}

# %%
type_problem_histogram(df[df['treatment']==1],'treatment')
type_prod_histogram(df[df['treatment']==1],'treatment')
# Out:
# {'age': 239, 'darkCircles': 35, 'acne': 103, 'dry': 125, 'redness': 7, 'sensitive': 81, 'oily': 103, 'normal': 143}
# {'oil': 14, 'cleanser': 21, 'exfoliator': 25, 'remover': 0, 'toner': 26, 'mist': 6, 'treatment': 388, 'serum': 150, 'lotion': 13, 'moisturizer': 62, 'balm': 1, 'mask': 20, 'peel': 12, 'lip': 3, 'eye': 34, 'supplment': 4, 'tool': 17}

# %%
type_problem_histogram(df[df['serum']==1],'serum')
type_prod_histogram(df[df['serum']==1],'serum')
# Out:
# {'age': 250, 'darkCircles': 12, 'acne': 71, 'dry': 137, 'redness': 20, 'sensitive': 86, 'oily': 88, 'normal': 136}
# {'oil': 12, 'cleanser': 11, 'exfoliator': 23, 'remover': 0, 'toner': 5, 'mist': 5, 'treatment': 150, 'serum': 392, 'lotion': 5, 'moisturizer': 52, 'balm': 2, 'mask': 7, 'peel': 22, 'lip': 3, 'eye': 29, 'supplment': 2, 'tool': 10}

# %%
type_problem_histogram(df[df['lotion']==1],'lotion')
type_prod_histogram(df[df['lotion']==1],'lotion')
# Out:
# {'age': 26, 'darkCircles': 3, 'acne': 12, 'dry': 22, 'redness': 3, 'sensitive': 14, 'oily': 10, 'normal': 19}
# {'oil': 5, 'cleanser': 9, 'exfoliator': 4, 'remover': 0, 'toner': 11, 'mist': 4, 'treatment': 13, 'serum': 5, 'lotion': 75, 'moisturizer': 36, 'balm': 2, 'mask': 3, 'peel': 2, 'lip': 2, 'eye': 5, 'supplment': 2, 'tool': 0}

# %%
type_problem_histogram(df[df['moisturizer']==1],'moisturizer')
type_prod_histogram(df[df['moisturizer']==1],'moisturizer')
# Out:
# {'age': 211, 'darkCircles': 24, 'acne': 52, 'dry': 192, 'redness': 25, 'sensitive': 94, 'oily': 95, 'normal': 149}
# {'oil': 5, 'cleanser': 17, 'exfoliator': 15, 'remover': 0, 'toner': 10, 'mist': 6, 'treatment': 62, 'serum': 52, 'lotion': 36, 'moisturizer': 439, 'balm': 12, 'mask': 12, 'peel': 9, 'lip': 4, 'eye': 23, 'supplment': 2, 'tool': 5}

# %%
type_problem_histogram(df[df['balm']==1],'balm')
type_prod_histogram(df[df['balm']==1],'balm')
# Out:
# {'age': 11, 'darkCircles': 4, 'acne': 0, 'dry': 22, 'redness': 4, 'sensitive': 12, 'oily': 1, 'normal': 14}
# {'oil': 2, 'cleanser': 1, 'exfoliator': 2, 'remover': 1, 'toner': 1, 'mist': 1, 'treatment': 1, 'serum': 2, 'lotion': 2, 'moisturizer': 12, 'balm': 35, 'mask': 1, 'peel': 0, 'lip': 8, 'eye': 2, 'supplment': 0, 'tool': 0}

# %%
type_problem_histogram(df[df['mask']==1],'mask')
type_prod_histogram(df[df['mask']==1],'mask')
# Out:
# {'age': 35, 'darkCircles': 10, 'acne': 14, 'dry': 27, 'redness': 4, 'sensitive': 6, 'oily': 17, 'normal': 28}
# {'oil': 3, 'cleanser': 10, 'exfoliator': 8, 'remover': 0, 'toner': 2, 'mist': 3, 'treatment': 20, 'serum': 7, 'lotion': 3, 'moisturizer': 12, 'balm': 1, 'mask': 102, 'peel': 3, 'lip': 3, 'eye': 6, 'supplment': 2, 'tool': 8}

# %%
type_problem_histogram(df[df['peel']==1],'peel')
type_prod_histogram(df[df['peel']==1],'peel')
# Out:
# {'age': 27, 'darkCircles': 10, 'acne': 17, 'dry': 20, 'redness': 0, 'sensitive': 14, 'oily': 18, 'normal': 24}
# {'oil': 2, 'cleanser': 8, 'exfoliator': 39, 'remover': 0, 'toner': 2, 'mist': 3, 'treatment': 12, 'serum': 22, 'lotion': 2, 'moisturizer': 9, 'balm': 0, 'mask': 3, 'peel': 53, 'lip': 2, 'eye': 5, 'supplment': 3, 'tool': 7}

# %%
type_problem_histogram(df[df['lip']==1],'lip')
type_prod_histogram(df[df['lip']==1],'lip')
# Out:
# {'age': 6, 'darkCircles': 2, 'acne': 0, 'dry': 16, 'redness': 2, 'sensitive': 9, 'oily': 0, 'normal': 5}
# {'oil': 3, 'cleanser': 3, 'exfoliator': 3, 'remover': 0, 'toner': 3, 'mist': 3, 'treatment': 3, 'serum': 3, 'lotion': 2, 'moisturizer': 4, 'balm': 8, 'mask': 3, 'peel': 2, 'lip': 23, 'eye': 4, 'supplment': 2, 'tool': 0}

# %%
type_problem_histogram(df[df['eye']==1],'eye')
type_prod_histogram(df[df['eye']==1],'eye')
# Out:
# {'age': 77, 'darkCircles': 47, 'acne': 7, 'dry': 41, 'redness': 6, 'sensitive': 12, 'oily': 16, 'normal': 32}
# {'oil': 2, 'cleanser': 10, 'exfoliator': 6, 'remover': 3, 'toner': 6, 'mist': 2, 'treatment': 34, 'serum': 29, 'lotion': 5, 'moisturizer': 23, 'balm': 2, 'mask': 6, 'peel': 5, 'lip': 4, 'eye': 136, 'supplment': 2, 'tool': 1}

# %%
type_problem_histogram(df[df['supplement']==1],'supplement')
type_prod_histogram(df[df['supplement']==1],'supplement')
# Out:
# {'age': 3, 'darkCircles': 2, 'acne': 2, 'dry': 2, 'redness': 0, 'sensitive': 0, 'oily': 2, 'normal': 0}
# {'oil': 2, 'cleanser': 2, 'exfoliator': 2, 'remover': 0, 'toner': 2, 'mist': 2, 'treatment': 4, 'serum': 2, 'lotion': 2, 'moisturizer': 2, 'balm': 0, 'mask': 2, 'peel': 3, 'lip': 2, 'eye': 2, 'supplment': 7, 'tool': 0}

# %%
type_problem_histogram(df[df['tool']==1],'tool')
type_prod_histogram(df[df['tool']==1],'tool')
# Out:
# {'age': 36, 'darkCircles': 12, 'acne': 26, 'dry': 23, 'redness': 5, 'sensitive': 12, 'oily': 14, 'normal': 27}
# {'oil': 0, 'cleanser': 22, 'exfoliator': 19, 'remover': 3, 'toner': 6, 'mist': 0, 'treatment': 17, 'serum': 10, 'lotion': 0, 'moisturizer': 5, 'balm': 0, 'mask': 8, 'peel': 7, 'lip': 0, 'eye': 1, 'supplment': 0, 'tool': 98}

# %%
#no makeup-removers that help with anti-aging
plt.figure(figsize=(5,5))
sns.scatterplot(x='makeup-removers',y='age',data=df)
#no makeup-removers that help with darkcircls
plt.figure(figsize=(5,5))
sns.scatterplot(x='makeup-removers',y='darkcircles',data=df)
#no makeup removers that help with redness
plt.figure(figsize=(5,5))
sns.scatterplot(x='makeup-removers',y='redness',data=df)
#no mists that help with acne
plt.figure(figsize=(5,5))
sns.scatterplot(x='mist',y='acne',data=df)
#no balms that help with acne
plt.figure(figsize=(5,5))
sns.scatterplot(x='balm',y='acne',data=df)
#no lip-care products that help with acne
plt.figure(figsize=(5,5))
sns.scatterplot(x='lip',y='acne',data=df)
#no peels that help with redness
plt.figure(figsize=(5,5))
sns.scatterplot(x='peel',y='redness',data=df)
#no supplements that help with redness
plt.figure(figsize=(5,5))
sns.scatterplot(x='supplement',y='redness',data=df)
#no supplements that help with sensitive skin
plt.figure(figsize=(5,5))
sns.scatterplot(x='supplement',y='sensitive',data=df)
#no supplements that help with normal/combination skin
plt.figure(figsize=(5,5))
sns.scatterplot(x='supplement',y='normal',data=df)
